# %% [markdown]
# # 환경변수 로딩

# %%
from dotenv import load_dotenv
import os

# .env 파일에서 환경 변수를 로드합니다.
load_dotenv(override=True)
PINECONE_API_KEY = os.environ['PINECONE_API_KEY']
# PINECONE_API_KEY

# %% [markdown]
# # pinecone 클라이언트 객체, index 객체 생성

# %%
from pinecone import Pinecone, ServerlessSpec

# pinecone 객체생성
pc = Pinecone(api_key=PINECONE_API_KEY)

index_name = ""

# index 객체 생성
index = pc.Index(index_name)
# Out:
# ---------------------------------------------------------------------------
# NotFoundException                         Traceback (most recent call last)
# Cell In[9], line 7
#       4 pc = Pinecone(api_key=PINECONE_API_KEY)
#       6 # index 객체 생성
# ----> 7 index = pc.Index("embedding-test")
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\pinecone.py:1387, in Pinecone.Index(self, name, host, **kwargs)
#    1384     index_host = normalize_host(host)
#    1385 else:
#    1386     # Otherwise, get host url from describe_index using the index name
# -> 1387     index_host = self.db.index._get_host(name)
#    1389 return _Index(
#    1390     host=index_host,
#    1391     api_key=api_key,
#    (...)
#    1395     **kwargs,
#    1396 )
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\db_control\resources\sync\index.py:292, in IndexResource._get_host(self, name)
#     290 def _get_host(self, name: str) -> str:
#     291     """:meta private:"""
# --> 292     return self._index_host_store.get_host(
#     293         api=self._index_api, config=self.config, index_name=name
#     294     )
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\db_control\index_host_store.py:47, in IndexHostStore.get_host(self, api, config, index_name)
#      45     return self._indexHosts[key]
#      46 else:
# ---> 47     description = api.describe_index(index_name)
#      48     self.set_host(config, index_name, description.host)
#      49     if not self.key_exists(key):
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)
#     100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\core\openapi\db_control\api\manage_indexes_api.py:1027, in ManageIndexesApi.__init__.<locals>.__describe_index(self, index_name, x_pinecone_api_version, **kwargs)
#    1025 kwargs["x_pinecone_api_version"] = x_pinecone_api_version
#    1026 kwargs["index_name"] = index_name
# -> 1027 return cast(IndexModel | ApplyResult[IndexModel], self.call_with_http_info(**kwargs))
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)
#     129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\api_client.py:320, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     299     return self.threadpool_executor.submit(
#     300         self.__call_api,
#     301         resource_path,
#    (...)
#     316         _check_type,
#     317     )
#     319 if not async_req:
# --> 320     return self.__call_api(
#     321         resource_path,
#     322         method,
#     323         path_params,
#     324         query_params,
#     325         header_params,
#     326         body,
#     327         post_params,
#     328         files,
#     329         response_type,
#     330         auth_settings,
#     331         _return_http_data_only,
#     332         collection_formats,
#     333         _preload_content,
#     334         _request_timeout,
#     335         _host,
#     336         _check_type,
#     337     )
#     339 return self.pool.apply_async(
#     340     self.__call_api,
#     341     (
#    (...)
#     358     ),
#     359 )
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\api_client.py:185, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     183 except PineconeApiException as e:
#     184     e.body = e.body.decode("utf-8")
# --> 185     raise e
#     187 self.last_response = response_data
#     189 return_data = response_data
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\api_client.py:173, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     164 url = build_request_url(
#     165     config=config,
#     166     processed_path_params=path_params_tuple,
#     167     resource_path=resource_path,
#     168     _host=_host,
#     169 )
#     171 try:
#     172     # perform request and return response
# --> 173     response_data = self.request(
#     174         method,
#     175         url,
#     176         query_params=processed_query_params,
#     177         headers=headers_tuple,
#     178         post_params=processed_post_params,
#     179         body=body,
#     180         _preload_content=_preload_content,
#     181         _request_timeout=_request_timeout,
#     182     )
#     183 except PineconeApiException as e:
#     184     e.body = e.body.decode("utf-8")
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\api_client.py:374, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     372 """Makes the HTTP request using RESTClient."""
#     373 if method == "GET":
# --> 374     return self.rest_client.GET(
#     375         url,
#     376         query_params=query_params,
#     377         _preload_content=_preload_content,
#     378         _request_timeout=_request_timeout,
#     379         headers=headers,
#     380     )
#     381 elif method == "HEAD":
#     382     return self.rest_client.HEAD(
#     383         url,
#     384         query_params=query_params,
#    (...)
#     387         headers=headers,
#     388     )
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:75, in RestClientInterface.GET(self, url, headers, query_params, _preload_content, _request_timeout)
#      72 def GET(
#      73     self, url, headers=None, query_params=None, _preload_content=True, _request_timeout=None
#      74 ):
# ---> 75     return self.request(
#      76         "GET",
#      77         url,
#      78         headers=headers,
#      79         _preload_content=_preload_content,
#      80         _request_timeout=_request_timeout,
#      81         query_params=query_params,
#      82     )
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:270, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     267     # log response body
#     268     logger.debug("response body: %s", r.data)
# --> 270 return raise_exceptions_or_return(r)
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:44, in raise_exceptions_or_return(r)
#      41     raise ForbiddenException(http_resp=r)
#      43 if r.status == 404:
# ---> 44     raise NotFoundException(http_resp=r)
#      46 if 500 <= r.status <= 599:
#      47     raise ServiceException(http_resp=r)
#
# NotFoundException: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'access-control-allow-origin': '*', 'vary': 'origin, access-control-request-method, access-control-request-headers', 'access-control-expose-headers': '*', 'x-pinecone-api-version': '2025-10', 'x-cloud-trace-context': 'b4779414e807eaba3fe87f06055af48d', 'date': 'Mon, 29 Dec 2025 03:28:59 GMT', 'server': 'Google Frontend', 'Content-Length': '89', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"NOT_FOUND","message":"Resource embedding-test not found"},"status":404}
